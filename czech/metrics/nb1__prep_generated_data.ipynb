# %% [markdown]
# # Notes:

# %% [raw]
# This notebook is only tested for czech data generated by Banksformer. Parts of it may be useful with other data, but no guarantees.
#
# The goal of this notebook is to ensure generated datasets have the correct columns so they can be used to compute results.
#
# Specifically, for each transaction we need:
#
# 1 - 'datetime'
# 2 - 'raw_amount'
# 3 - At least one of:
#   -- (A) columns for each code in 'cat_code_fields' or
#   -- (B) tcode column which is a concatination of the codes in 'cat_code_fields'
#   -- (C) tcode column with 'shortnames' and information in 'codenames.py' for converting (deprecated)

# %%
import os
import pandas as pd
import sys

# %%
from_dir = "generated_data/" # process all .csv files from this directory
to_dir = "generated_data/"   # write all updated .csv files to this directory

# %%
## NOTE: These methods are only valid for czech data! 
from mylib.preprocessing import set_code_fields

def set_datetime(df):
    
    if not "datetime" in df.columns:
        
        df["datetime"] = df["date"]
        
        
 
def set_raw_amount(df):
    df["raw_amount"] = df.amount * df.type.apply(lambda x: -1 if x == "DEBIT" else 1)  
    

def set_codes(df):
    pass



def prep_df(df, convert_shortnames = False):
    set_code_fields(df, convert_shortnames = convert_shortnames, raise_if_nonmatch=True)
    set_datetime(df)
    set_raw_amount(df)
    set_codes(df)

# %%
from mylib.dataset_params import CAT_CODE_FIELDS

# %%
CAT_CODE_FIELDS
# Out:
# ['k_symbol', 'operation', 'type']

# %% [raw]
# all([x not in df.columns for x in CAT_CODE_FIELDS])

# %% [raw]
# all([x + "_num" in df.columns for x in CAT_CODE_FIELDS])

# %% [raw]
# [x + "_num" in df.columns for x in CAT_CODE_FIELDS]

# %% [raw]
# if not (all([x in df.columns for x in CAT_CODE_FIELDS]) or ("raw_tcode" in df.columns ) or "tcode" in df.columns):
#     if all([x + "_num" in df.columns for x in CAT_CODE_FIELDS]):

# %%
failed_on = []


if 'updated_dfs.txt' in os.listdir("generated_data/"):
    with open("generated_data/updated_dfs.txt") as f:
        already_updated = [line.strip() for line in f.readlines()]

else: 
    with open("generated_data/updated_dfs.txt", 'w') as f:
        already_updated = []
    

    
with open("generated_data/updated_dfs.txt", "a") as f: 
    


    for fname in os.listdir(from_dir):
        path = from_dir + fname
        
        print("On", fname)

        if not ".csv" in fname or fname in already_updated:
            print("\n")
            continue 


#         if  "f-cz" in fname: #"v2a" in fname or
#             convert_shortnames = True
#         else:
#             convert_shortnames = False
        # convert_shortnames = False

    
        df = pd.read_csv(path)
        
        if "tcode" in df.columns:
            convert_shortnames = 'interest_cr' in df.tcode.unique()
        else:
            convert_shortnames = False
        
        if "gen_v2a__" in fname:
            try:
                df = df.drop(columns=["tcode", "raw_tcode"])
                print("dropped:","tcode", "raw_tcode")
            except:
                print("Didnt drop:","tcode", "raw_tcode")
        
        if True:
        # try:
            prep_df(df, convert_shortnames)
            
            if not "datetime" in df.columns:
                df["datetime"] = df["date"]
        
        
            if "CREDIT" in df.k_symbol.unique():
                df.rename(columns={'k_symbol': 'type', 'operation': 'k_symbol', 'type':'operation'}, inplace=True)
            
        
            df.to_csv(to_dir + fname, index=False)
            print("Updated:", fname)
        # except Exception as e:
        #     failed_on.append((fname, e, df))
        #     print(f"Failed to update: {path}. ({e})", )

        print("\n")

        f.writelines(fname+"\n")
# Out:
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2a__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gtg_0-hd_48-nl_3-bs_32--len_80.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_80-v2.csv
#
#
# On gtg_0-hd_24-nl_4-bs_32--len_100.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_80-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gtg_0-hd_48-nl_4-bs_32--len_80.csv
#
#
# On t-gen_v2a__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2 2.csv
#
#
# On tg_0-hd_24-nl_4-bs_64--len_100.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b-v__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_3-dm_32-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_128-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_32-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_80-v2.csv
#
#
# On gen_v2b-v__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_128-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2 2.csv
#
#
# On gen_v2b__nld_3-dm_32-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_32-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2a__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b-nd__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gtg_0-hd_48-nl_3-bs_32--len_100.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_80-v2.csv
#
#
# On tg_1-hd_24-nl_4-bs_64--len_100.csv
#
#
# On gen_v2b-nc__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
# Updated: gen_v2b-nc__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b-v__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_100-v2.csv
#
#
# On h-gtg_0-hd_48-nl_3-bs_32--len_80.csv
#
#
# On t-gen_v2b__nld_3-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_32-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b-nd__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_80-v2.csv
#
#
# On gen_v2b-nd__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_32-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b-nc__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
# Updated: gen_v2b-nc__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_3-dm_128-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2a__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gtg_0-hd_48-nl_4-bs_32--len_80.csv
#
#
# On h-gen_v2b-nd__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2a__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b-v__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On updated_dfs.txt
#
#
# On gen_v2b__nld_3-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_100-v2.csv
#
#
# On h-gen_v2a__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b-nd__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_32-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On t-gtg_0-hd_24-nl_3-bs_32--len_80.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_80-v2.csv
#
#
# On h-gen_v2b-v__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2a__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2 2.csv
# Didnt drop: tcode raw_tcode
# Updated: gen_v2a__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2 2.csv
#
#
# On gtg_0-hd_24-nl_3-bs_32--len_100.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_3-dm_32-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_100-v2.csv
#
#
# On h-gtg_0-hd_24-nl_4-bs_32--len_80.csv
#
#
# On t-gen_v2b__nld_3-dm_32-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_80-v2.csv
#
#
# On tg_2-hd_24-nl_4-bs_64--len_100.csv
#
#
# On h-gen_v2b__nld_3-dm_128-nh_4-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gtg_0-hd_48-nl_4-bs_32--len_100.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_80-v2.csv
#
#
# On gen_v2b-v__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b-nd__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_128-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_3-dm_32-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b-v__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_80-v2.csv
#
#
# On h-gen_v2b__nld_3-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On .ipynb_checkpoints
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_80-v2.csv
#
#
# On gen_v2b-nd__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On h-gtg_0-hd_24-nl_3-bs_32--len_80.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_32--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On h-gen_v2b-v__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_256--vf1-len_80-v2.csv
#
#
# On gen_v2b-nd__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_3-dm_128-nh_4-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On t-gtg_0-hd_24-nl_4-bs_32--len_80.csv
#
#
# On h-gen_v2b__nld_3-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b-nd__nld_4-dm_128-nh_2-i_2-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b-nc__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
# Updated: gen_v2b-nc__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_32-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_100-v2.csv
#
#
# On h-gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_80-v2.csv
#
#
# On t-gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_32--vf1-len_100-v2.csv
#
#
# On t-gen_v2b__nld_3-dm_32-nh_2-i_1-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_3-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_64--vf1-len_100-v2.csv
#
#
# On h-gen_v2b-v__nld_4-dm_128-nh_2-i_1-dr_0__1-opt_adam-lwi_0-bs_64--vf1-len_80-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_moredate-bs_64--vf1-len_100-v2.csv
#
#
# On gen_v2b__nld_4-dm_128-nh_2-i_0-dr_0__1-opt_adam-lwi_mid-bs_128--vf1-len_100-v2.csv

# %% [raw]
# failed_on = []
#
#
# if 'updated_dfs.txt' in os.listdir("generated_data/"):
#     with open("generated_data/updated_dfs.txt") as f:
#         already_updated = [line.strip() for line in f.readlines()]
#
# else:
#     with open("generated_data/updated_dfs.txt", 'w') as f:
#         already_updated = []
#
#
#
# with open("generated_data/updated_dfs.txt", "a") as f:
#
#
#
#     for fname in os.listdir(from_dir):
#         path = from_dir + fname
#
#         if not ".csv" in fname or fname in already_updated:
#             continue
#
#
#         # if "v2a" in fname or "f-cz" in fname:
#         #     convert_shortnames = True
#         # else:
#         #     convert_shortnames = False
#
#         convert_shortnames = False
#
#         df = pd.read_csv(path)
#
#         # if True:
#         try:
#             prep_df(df, convert_shortnames)
#
#
#             if "CREDIT" in df.k_symbol.unique():
#                 df.rename(columns={'k_symbol': 'type', 'operation': 'k_symbol', 'type':'operation'}, inplace=True)
#
#
#             df.to_csv(to_dir + fname, index=False)
#             print("Updated:", fname)
#         except Exception as e:
#             failed_on.append((fname, e, df))
#             print(f"Failed to update: {path}. ({e})", )
#
#         print("\n")
#
#         f.writelines(fname+"\n")

# %%
df.tcode

# %%
df.raw_tcode

# %%
fname

# %%
df.tcode

# %% [raw]
# l

# %% [raw]
# "aaaaa".replace("a", "B")

# %% [raw]
# df

# %% [raw]
# import pandas as pd

# %% [raw]
# pd.read_csv("generated_data/v2a-gen_nld_4-d_model_32-num_heads_4-i_0-dr_0__1-dff_32-opt_adam-l_loss_mse_lwi-0--vf1-len_80-v2.csv")

# %% [raw]
# df = pd.read_csv("generated_data/v2b-gen_nld_4-d_model_32-num_heads_4-i_0-dr_0__1-dff_32-opt_adam-l_loss_mse_lwi-moredate--vf1-len_80-v2.csv")
